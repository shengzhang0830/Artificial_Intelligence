# %% [markdown]
# ## Text Processing ##

# %% [markdown]
# Text processing plays a very important role in NLP. It is the essential first step for almost all NLP approaches. It involves processing a text corpus (a collection of documents where a document consists of a set of words). The processing involves several steps which include:
# * Parsing
# * Tokenization
# * Stemming
#
# In addition we often perform some type of text statistics which usually involves counting the number of times words appear in a collection.
#
#
# In this lab session we are going to cover all of these steps and utilize them to process Amazon product reviews. This dataset was provided to us by Prof. Julian McAuley from UCSD who reminded me to make sure that we cite his papers that use this data:
# * R. He, J. McAuley. Modeling the visual evolution of fashion trends with one-class collaborative filtering. WWW, 2016
# * J. McAuley, C. Targett, J. Shi, A. van den Hengel. Image-based recommendations on styles and substitutes. SIGIR, 2015

# %% [markdown]
# This dataset consists of reviews across 24 different product categories with a total number of $\approx$142 million reviews. For this lab session we will be using a subset of 1000 reviews from the "Cell Phones and Accessories" category whose original set contains $\approx$200k reviews.
# All throughout this lab session we will be using the nltk package:
# http://www.nltk.org

# %% [markdown]
# The reviews data is semi-structured and is in a json file format. Below is the data structure of one such review:
# `
# {
#   "reviewerID": "A3HVRXV0LVJN7",
#   "asin": "0110400550",
#   "reviewerName": "BiancaNicole",
#   "helpful": [
#     4,
#     4
#   ],
#   "reviewText": "Best phone case ever . Everywhere I go I get a ton of compliments on it. It was in perfect condition as well.",
#   "overall": 5.0,
#   "summary": "A++++",
#   "unixReviewTime": 1358035200,
#   "reviewTime": "01 13, 2013"
# }
# `
#
# This dataset comes with a set of python functions that will help us convert the reviews from json format to pandas dataframes.

# %%
def parse(path):
    g = gzip.open(path, 'rb')
    for l in g:
        yield eval(l)

def getDF(path):
    i = 0
    df = {}
    for d in parse(path):
        df[i] = d
        i += 1
    return pd.DataFrame.from_dict(df, orient='index')

# %% [markdown]
# Using these helper functions we'll first extract the reviews:

# %%
import pandas as pd
import gzip

review_file = "../../../data/amazon_reviews/cp/reviews_Cell_Phones_and_Accessories_h1k.json.gz"

df = getDF(review_file)
print (df['reviewText'])
# Out:
# 0      The case pictured is a soft violet color, but ...
# 1      Saw this same case at a theme park store for 2...
# 2      case fits perfectly and I always gets complime...
# 3      Best phone case ever . Everywhere I go I get a...
# 4      It may look cute. This case started off pretty...
# 5      ITEM NOT SENT from Blue Top Company in Hong Ko...
# 6      this is a cute case, I bought it for my wife b...
# 7      it came in ok but there was a crack on the lef...
# 8      The case is good, but the two pieces do not fi...
# 9      I got this for my 14 year old sister.  She lov...
# 10     The case is super cute, durable, and a convers...
# 11     I had to super glue the two parts together bec...
# 12     This case is extremely durabl;e. I've dropped ...
# 13     I ordered this as a birthday present for my si...
# 14     I ordered this and received it within two week...
# 15     I like the case for its colors, but the lower ...
# 16     As excited as I was to purchase this item, the...
# 17     I got the case very quick and way before the e...
# 18     slips off almost broke my phone instead... but...
# 19     I was expecting a cute case that fit my Verizo...
# 20     this case is very pretty and cool but its not ...
# 21     I got the item very quickly and it fits my pho...
# 22     Cheap plastic doesn't stay together over the p...
# 23     The case did not stay together the bottom piec...
# 24     It took over a month and a half for this produ...
# 25     Although I received this case very quickly, mi...
# 26     This is a terrible product. I couldn't even us...
# 27     It cracks easy but its a nice case and i got a...
# 28     I love this case.  I've had it for a few years...
# 29     The top part of the case got stuck on my phone...
#                              ...
# 970    I have had this one on my phone since I purcha...
# 971    This case arrived on time, and it looks the sa...
# 972    Realy like this!! Very colorful as I had hoped...
# 973    My husband wore out his OtterBox and I gave hi...
# 974    I recently purchased and received this case fo...
# 975    Really pretty case but the colors on this Evo ...
# 976    Received this item very quickly. The design is...
# 977    I ordered this along with several other HTC Ev...
# 978    The design doesnt have all the purple like it ...
# 979    I drop my phone often and it has not broken at...
# 980    I found this on Amazon right after I paid $20....
# 981    Pretty, but not as bright and vivid as in the ...
# 982    My mom & i had the same phone case.Im kind of ...
# 983    yes would recommend, fun design, little less s...
# 984    I wanted to highly recommend this seller>I had...
# 985    Its beautiful and sturdy but the paint chips e...
# 986    this cover makes an old phone look and feel ne...
# 987    I am very unhappy with the product.  I expecte...
# 988    When i recieved it the first time it was white...
# 989    Upon ordering the Phone Case, I received it ti...
# 990    These are cheap but worked great for my phone....
# 991    I have had my phone for about two years with t...
# 992    Fits nicely, I'm really enjoying the cover.  I...
# 993    I LOVE this case! I got it for my samsung gala...
# 994    My brother loves this case . well built and be...
# 995    The color of the case isn't as bright as the p...
# 996    this is the second faceplate for my phone that...
# 997    this case lasted me all through the month of d...
# 998    The case is pretty.Sadly though the packaging ...
# 999    This case is extremely durable with the combin...
# Name: reviewText, Length: 1000, dtype: object

# %% [markdown]
# Now that we've extracted the review fields we'll tokenize them. More specifically in this next step we'll perform the following:
# * Extract sentences
# * Tokenize words
# * Remove stopwords
#
# We'll use the "nltk.sent_tokenize" method to extract sentences from the text and the "nltk.word_tokenize" method to tokenize words in a sentence.

# %%
import nltk
#load the nltk default English stopwords list:
stopwords_list = nltk.corpus.stopwords.words('english')
all_words = list()
tokenized_sent = list()
r_count=0
for review in df['reviewText']:
    r_count+=1
    if (r_count%100==0):
        print (r_count)
    sentences = nltk.sent_tokenize(review)
    for sentence in sentences:
        sent_tok = nltk.word_tokenize(sentence)
        #remove stopwords:
        sent_tok = [word for word in sent_tok if word not in stopwords_list]
        print (" Original=["+sentence+"]")
        #create a tokenized version of the sentence:
        sent_tok_str = " ".join(word for word in sent_tok)
        print ("Tokenized=["+sent_tok_str+"]")
        #create a list of all tokenized words across all sentences:
        for word in sent_tok:
            all_words.append(word.lower())
# Out:
#  Original=[The case pictured is a soft violet color, but the case cover I received was a dark purple.]
# Tokenized=[The case pictured soft violet color , case cover I received dark purple .]
#  Original=[While I'm sure the quality of the product is fine, the color is very different.]
# Tokenized=[While I 'm sure quality product fine , color different .]
#  Original=[Saw this same case at a theme park store for 25 dollars.]
# Tokenized=[Saw case theme park store 25 dollars .]
#  Original=[This is very good quality for a great price.]
# Tokenized=[This good quality great price .]
#  Original=[case fits perfectly and I always gets compliments on it its hasn't cracked when I dropped it.]
# Tokenized=[case fits perfectly I always gets compliments n't cracked I dropped .]
#  Original=[wonderful and protective.]
# Tokenized=[wonderful protective .]
#  Original=[Best phone case ever .]
# Tokenized=[Best phone case ever .]
#  Original=[Everywhere I go I get a ton of compliments on it.]
# Tokenized=[Everywhere I go I get ton compliments .]
#  Original=[It was in perfect condition as well.]
# Tokenized=[It perfect condition well .]
#  Original=[It may look cute.]
# Tokenized=[It may look cute .]
#  Original=[This case started off pretty good the first couple of weeks.]
# Tokenized=[This case started pretty good first couple weeks .]
#  Original=[Then it started to slide off.]
# Tokenized=[Then started slide .]
#  Original=[It slid off one day I was in a parking lot phone fell face down and my glass shattered.]
# Tokenized=[It slid one day I parking lot phone fell face glass shattered .]
#  Original=[TERRIBLE CASE!!!!]
# Tokenized=[TERRIBLE CASE ! ! ! !]
#  Original=[!]
# Tokenized=[!]
#  Original=[ITEM NOT SENT from Blue Top Company in Hong Kong and it's been over two months!]
# Tokenized=[ITEM NOT SENT Blue Top Company Hong Kong 's two months !]
#  Original=[I will report this.]
# Tokenized=[I report .]
#  Original=[DO NOT use this company.]
# Tokenized=[DO NOT use company .]
#  Original=[Not happy at all!]
# Tokenized=[Not happy !]
#  Original=[this is a cute case, I bought it for my wife but it was really hard to take off considering it was way too tight for the phone.]
# Tokenized=[cute case , I bought wife really hard take considering way tight phone .]
#  Original=[When I put it on for her, it caused the screen protector to bubble up.]
# Tokenized=[When I put , caused screen protector bubble .]
#  Original=[I thought I was gonna end up breaking it when trying to remove it.]
# Tokenized=[I thought I gon na end breaking trying remove .]
#  Original=[She liked the look of it but that's about it.]
# Tokenized=[She liked look 's .]
#  Original=[it came in ok but there was a crack on the left side.]
# Tokenized=[came ok crack left side .]
#  Original=[also it slides apart really easily but it's fine.]
# Tokenized=[also slides apart really easily 's fine .]
#  Original=[The case is good, but the two pieces do not fit all the way together.]
# Tokenized=[The case good , two pieces fit way together .]
#  Original=[It is slightly off and no matter how much I tried(even shaving the side a little) it wouldn't slide into each other.]
# Tokenized=[It slightly matter much I tried ( even shaving side little ) would n't slide .]
#  Original=[The gap is very, very little and you can barley notice it.]
# Tokenized=[The gap , little barley notice .]
#  Original=[The bottom of the case has never slid off, so I will deal with it for the wonderful price!]
# Tokenized=[The bottom case never slid , I deal wonderful price !]
#  Original=[I got this for my 14 year old sister.]
# Tokenized=[I got 14 year old sister .]
#  Original=[She loves it.]
# Tokenized=[She loves .]
#  Original=[I really really don't have any complaints.]
# Tokenized=[I really really n't complaints .]
#  Original=[Yeah]
# Tokenized=[Yeah]
#  Original=[The case is super cute, durable, and a conversation starter.]
# Tokenized=[The case super cute , durable , conversation starter .]
#  Original=[The delivery was before the estimated date, and the case it's self is well made.Since it's 2 separate pieces, it isn't perfectly snug, so i slip a little piece of paper on my phone before I put on the dripping part.]
# Tokenized=[The delivery estimated date , case 's self well made.Since 's 2 separate pieces , n't perfectly snug , slip little piece paper phone I put dripping part .]
#  Original=[If it arrives and the dripping part slides, just try using that method.The colors are exactly as pictures and it's really neat since the white part is a different texture than the pink part.Overall, 4/5 stars.]
# Tokenized=[If arrives dripping part slides , try using method.The colors exactly pictures 's really neat since white part different texture pink part.Overall , 4/5 stars .]
#  Original=[I had to super glue the two parts together because it would come apart and my phone would slide out of the case and fall.]
# Tokenized=[I super glue two parts together would come apart phone would slide case fall .]
#  Original=[Also the color is much more bland than in the picture]
# Tokenized=[Also color much bland picture]
#  Original=[This case is extremely durabl;e. I've dropped my phone atleast ten times ( I'm clumsy) since I got this case.]
# Tokenized=[This case extremely durabl ; e. I 've dropped phone atleast ten times ( I 'm clumsy ) since I got case .]
#  Original=[Still no cracks in the case.]
# Tokenized=[Still cracks case .]
#  Original=[My favorite part about this switcheasy case is that the plastic goes over the front of my phone, so no matter how many times it drops face down, the screen is protected from cracking.]
# Tokenized=[My favorite part switcheasy case plastic goes front phone , matter many times drops face , screen protected cracking .]
#  Original=[I ordered this as a birthday present for my sister.]
# Tokenized=[I ordered birthday present sister .]
#  Original=[It arrived quickly, but I was very disappointed.]
# Tokenized=[It arrived quickly , I disappointed .]
#  Original=[The item was loose, the cover slipped off whenever I tried to lock my phone, the pieces didn't even fit together, the color doesn't match the picture.]
# Tokenized=[The item loose , cover slipped whenever I tried lock phone , pieces n't even fit together , color n't match picture .]
#  Original=[This is one of the worst items I've ever bought.]
# Tokenized=[This one worst items I 've ever bought .]
#  Original=[Terrible item.]
# Tokenized=[Terrible item .]
#  Original=[I see no reason for the sale of this, this item is completely USELESS.]
# Tokenized=[I see reason sale , item completely USELESS .]
#  Original=[I ordered this and received it within two weeks.]
# Tokenized=[I ordered received within two weeks .]
#  Original=[The bottom piece slides into the top very snugly, and the whole case does not come apart.]
# Tokenized=[The bottom piece slides top snugly , whole case come apart .]
#  Original=[It's a great phone case and I would definitely buy it again.]
# Tokenized=[It 's great phone case I would definitely buy .]
#  Original=[I like the case for its colors, but the lower part where it should snap onto the upper part, comes off easily.]
# Tokenized=[I like case colors , lower part snap onto upper part , comes easily .]
#  Original=[As excited as I was to purchase this item, the day that it arrived had me on cloud 9.]
# Tokenized=[As excited I purchase item , day arrived cloud 9 .]
#  Original=[No more worrying about potentially dropping my phone and breaking it.]
# Tokenized=[No worrying potentially dropping phone breaking .]
#  Original=[However sadly this case was not worth the money invested.]
# Tokenized=[However sadly case worth money invested .]
#  Original=[The top piece did not fit with the bottom piece so one sad day at Disneyland,upon retrieving my phone, the top piece slid right off, remaining in my hands while my iPhone hit the asphalt, cracking right down the middle.]
# Tokenized=[The top piece fit bottom piece one sad day Disneyland , upon retrieving phone , top piece slid right , remaining hands iPhone hit asphalt , cracking right middle .]
#  Original=[Clearly purchasing this case was a HUGE mistake.]
# Tokenized=[Clearly purchasing case HUGE mistake .]
#  Original=[I got the case very quick and way before the expected date!]
# Tokenized=[I got case quick way expected date !]
#  Original=[It came perfect and is really easy to put together.]
# Tokenized=[It came perfect really easy put together .]
#  Original=[Super cute!Also, I have dropped my phone many times in the case since its been bought on concrete and asphalt and my phone has not one scratch and crack.]
# Tokenized=[Super cute ! Also , I dropped phone many times case since bought concrete asphalt phone one scratch crack .]
#  Original=[Way better than an otterbox]
# Tokenized=[Way better otterbox]
#  Original=[slips off almost broke my phone instead... but the quality was nice the details]
# Tokenized=[slips almost broke phone instead ... quality nice details]
#  Original=[I was expecting a cute case that fit my Verizon iPhone 4S well.]
# Tokenized=[I expecting cute case fit Verizon iPhone 4S well .]
#  Original=[I got it in the mail and I was so excited to try it on my phone.]
# Tokenized=[I got mail I excited try phone .]
#  Original=[It barely fits.]
# Tokenized=[It barely fits .]
#  Original=[The button holes don't fit the buttons.]
# Tokenized=[The button holes n't fit buttons .]
#  Original=[(Too high up) Another thing is the melt thingies near the fromt canera and stuff kept peeling my screen protector off whenever i tried to put it on.]
# Tokenized=[( Too high ) Another thing melt thingies near fromt canera stuff kept peeling screen protector whenever tried put .]
#  Original=[i fell head over heels with this case and I'm so upset it doesn't fit right..]
# Tokenized=[fell head heels case I 'm upset n't fit right..]
#  Original=[If you have the Verizon iPhone 4S, sadly, beware..]
# Tokenized=[If Verizon iPhone 4S , sadly , beware..]
#  Original=[this case is very pretty and cool but its not protective with this case on i cracked my phone 3 times.]
# Tokenized=[case pretty cool protective case cracked phone 3 times .]
#  Original=[I got the item very quickly and it fits my phone perfectly!]
# Tokenized=[I got item quickly fits phone perfectly !]
#  Original=[Would totally order again and recommend this to anyone who wants this case]
# Tokenized=[Would totally order recommend anyone wants case]
#  Original=[Cheap plastic doesn't stay together over the phone.]
# Tokenized=[Cheap plastic n't stay together phone .]
#  Original=[It is not durable.]
# Tokenized=[It durable .]
#  Original=[Waste of money.]
# Tokenized=[Waste money .]
#  Original=[Will not use the item]
# Tokenized=[Will use item]
#  Original=[The case did not stay together the bottom piece kept falling off.]
# Tokenized=[The case stay together bottom piece kept falling .]
#  Original=[It was cute but also the hole for the camara was kind small looking.]
# Tokenized=[It cute also hole camara kind small looking .]
#  Original=[But was not too bad fort he price]
# Tokenized=[But bad fort price]
#  Original=[It took over a month and a half for this product to be delivered to me.]
# Tokenized=[It took month half product delivered .]
#  Original=[Not only that, but once I received it in the mail, it was cracked!]
# Tokenized=[Not , I received mail , cracked !]
#  Original=[This plastic case is not durable and the melting indent is quite annoying after some time.]
# Tokenized=[This plastic case durable melting indent quite annoying time .]
#  Original=[It's sorta hard to grip too.]
# Tokenized=[It 's sorta hard grip .]
#  Original=[Would not recommend.]
# Tokenized=[Would recommend .]
#  Original=[Although I received this case very quickly, mine seems to be a dud.]
# Tokenized=[Although I received case quickly , mine seems dud .]
#  Original=[The top and bottom parts slide together, but do not lock in place.]
# Tokenized=[The top bottom parts slide together , lock place .]
#  Original=[I tried using it anyway, and my phone slid out of my case and shot onto the street.]
# Tokenized=[I tried using anyway , phone slid case shot onto street .]
#  Original=[It's such a cute case, and I'm gotten tons of compliments, but I definitely got what I paid for.]
# Tokenized=[It 's cute case , I 'm gotten tons compliments , I definitely got I paid .]
#  Original=[This is a terrible product.]
# Tokenized=[This terrible product .]
#  Original=[I couldn't even use it.]
# Tokenized=[I could n't even use .]
#  Original=[The pieces don't fit together it just falls right off the phone.]
# Tokenized=[The pieces n't fit together falls right phone .]
#  Original=[It's terrible.]
# Tokenized=[It 's terrible .]
#  Original=[It cracks easy but its a nice case and i got a lot of complements on it.]
# Tokenized=[It cracks easy nice case got lot complements .]
#  Original=[Its cheap but i guess its worth it.]
# Tokenized=[Its cheap guess worth .]
#  Original=[I love this case.]
# Tokenized=[I love case .]
#  Original=[I've had it for a few years now and I've never had any problems with it.]
# Tokenized=[I 've years I 've never problems .]
#  Original=[It snaps on just right!]
# Tokenized=[It snaps right !]
#  Original=[The top part of the case got stuck on my phone and i had an extremely hard time removing it.]
# Tokenized=[The top part case got stuck phone extremely hard time removing .]
#  Original=[amazing exactly what i wanted and more.]
# Tokenized=[amazing exactly wanted .]
#  Original=[Came with a lot of extra things i didnt know were coming.]
# Tokenized=[Came lot extra things didnt know coming .]
#  Original=[Very impressed]
# Tokenized=[Very impressed]
#  Original=[I really loved the color combination and how the design showed up on the front as well.]
# Tokenized=[I really loved color combination design showed front well .]
#  Original=[I bought this for my iPhone 4s, and unfortunately, it doesn't stay on.]
# Tokenized=[I bought iPhone 4s , unfortunately , n't stay .]
#  Original=[It comes in two pieces, one white piece that snugly fits on the bottom, and the pink drip portion that slides over the white piece.]
# Tokenized=[It comes two pieces , one white piece snugly fits bottom , pink drip portion slides white piece .]
#  Original=[It's the pink piece that makes this unfortunate.]
# Tokenized=[It 's pink piece makes unfortunate .]
#  Original=[It doesn't click with the white piece at all, and it easily slides off.]
# Tokenized=[It n't click white piece , easily slides .]
#  Original=[I wanted so much to keep this case on, but I also didn't wanna risk my phone having a giant crack on the screen due to a case that doesn't stay on.]
# Tokenized=[I wanted much keep case , I also n't wan na risk phone giant crack screen due case n't stay .]
#  Original=[For the price, it is neat, but I really doubt I'm going to keep it on my phone.]
# Tokenized=[For price , neat , I really doubt I 'm going keep phone .]
#  Original=[What a bummer.]
# Tokenized=[What bummer .]
#  Original=[It is cute and light weight.]
# Tokenized=[It cute light weight .]
#  Original=[The big drawback is it blocks WIFI signals at my work.]
# Tokenized=[The big drawback blocks WIFI signals work .]
#  Original=[The WIFI signal is also bad if I am in the back yard of my house.]
# Tokenized=[The WIFI signal also bad I back yard house .]
#  Original=[The router is in the living room.]
# Tokenized=[The router living room .]
#  Original=[I used up more 3G and learned that the WIFI signals improved one bar or so after remove my case.]
# Tokenized=[I used 3G learned WIFI signals improved one bar remove case .]
#  Original=[I don't know what blocks it, but I tested many times and convinced that it does block WIFI signals.]
# Tokenized=[I n't know blocks , I tested many times convinced block WIFI signals .]
#  Original=[The case in the photo looks great and very cute; however, when it arrives, it comes scratched up, flimsy and not worth $8 at all.]
# Tokenized=[The case photo looks great cute ; however , arrives , comes scratched , flimsy worth $ 8 .]
#  Original=[Needless to say, I returned the product.]
# Tokenized=[Needless say , I returned product .]
#  Original=[I got this case for my new 4s ,( I have the white one )& love it , its very cute .]
# Tokenized=[I got case new 4s , ( I white one ) & love , cute .]
#  Original=[It snaps on easily and comes off better than some of my other cases.]
# Tokenized=[It snaps easily comes better cases .]
#  Original=[I like how the top & bottom is completely open so my charger & headphones fit perfectly .]
# Tokenized=[I like top & bottom completely open charger & headphones fit perfectly .]
#  Original=[The only down side is that it dose not provide any protection other than from scratches so if you drop your phone a lot than I wouldn't recommend this case but if you don't than I think it's a great value.]
# Tokenized=[The side dose provide protection scratches drop phone lot I would n't recommend case n't I think 's great value .]
#  Original=[This is my art offered on this case without my permission.]
# Tokenized=[This art offered case without permission .]
#  Original=[This is art theft and it will be reported if not removed from sale..]
# Tokenized=[This art theft reported removed sale..]
#  Original=[can not describe how much I loved and enoyed this case, its not so much great for protecting the phone but for minimal coverage...but loved the look and feel of the case its self....]
# Tokenized=[describe much I loved enoyed case , much great protecting phone minimal coverage ... loved look feel case self ... .]
#  Original=[Great cover and design fits awesome doesn`t provide a whole lotof protection but a good case for any sea lover]
# Tokenized=[Great cover design fits awesome doesn`t provide whole lotof protection good case sea lover]
#  Original=[I was sent the wrong product.]
# Tokenized=[I sent wrong product .]
#  Original=[I did not receive the Nook Color Easel, but a cover for another type of Nook product.]
# Tokenized=[I receive Nook Color Easel , cover another type Nook product .]
#  Original=[this cover is very well made and also convenient to use.It is durable and protects my Nook from scratches.It is very easy to remove the Nook from the cover.]
# Tokenized=[cover well made also convenient use.It durable protects Nook scratches.It easy remove Nook cover .]
#  Original=[I definitely like this product a lot.]
# Tokenized=[I definitely like product lot .]
#  Original=[I've had the regular Nook cover where it would flip open as a book and didn't like it as much.]
# Tokenized=[I 've regular Nook cover would flip open book n't like much .]
#  Original=[The easel lets me read pretty much hands free.]
# Tokenized=[The easel lets read pretty much hands free .]
#  Original=[I've received the one that opens toward the side (like a book) instead of this one.]
# Tokenized=[I 've received one opens toward side ( like book ) instead one .]
#  Original=[I asked for replacement and they answered that they didn't have that on stock and that they've sent something that I might like.]
# Tokenized=[I asked replacement answered n't stock 've sent something I might like .]
#  Original=[Anyway  I've received the refund with a note to keep the one they sent me.]
# Tokenized=[Anyway I 've received refund note keep one sent .]
#  Original=[After searching many places for many cases/covers, I have finally found THE case!]
# Tokenized=[After searching many places many cases/covers , I finally found THE case !]
#  Original=[It fits my Nook nicely, easy to use, and is very neat looking on my nook.]
# Tokenized=[It fits Nook nicely , easy use , neat looking nook .]
#  Original=[I highly recommend this case.]
# Tokenized=[I highly recommend case .]
#  Original=[This case will allow your nook to stand on its own while you read hands free.]
# Tokenized=[This case allow nook stand read hands free .]
#  Original=[Very sturdy and of good quality.]
# Tokenized=[Very sturdy good quality .]
#  Original=[We purchased the Nook Color because it has internet capability.]
# Tokenized=[We purchased Nook Color internet capability .]
#  Original=[It is much lighter than carrying the laptop and easy to use.]
# Tokenized=[It much lighter carrying laptop easy use .]
#  Original=[We have had some problems with connecting to the internet at times.]
# Tokenized=[We problems connecting internet times .]
#  Original=[All I have to say  is my Blackberry is very happy with its new body.]
# Tokenized=[All I say Blackberry happy new body .]
#  Original=[The vendor was very prompt.]
# Tokenized=[The vendor prompt .]
#  Original=[Thank you .]
# Tokenized=[Thank .]
#  Original=[Well the product was good other than the screen wasnt attatched to the rest of the body and my glue kept coming off, but they sent me more.]
# Tokenized=[Well product good screen wasnt attatched rest body glue kept coming , sent .]
#  Original=[I ordered this for my little sister's phone and she loves it.]
# Tokenized=[I ordered little sister 's phone loves .]
#  Original=[The color is nice and beautiful.]
# Tokenized=[The color nice beautiful .]
#  Original=[Installation was easy.]
# Tokenized=[Installation easy .]
#  Original=[Delivery was quick and it was package nicley.]
# Tokenized=[Delivery quick package nicley .]
#  Original=[Will definately order from this seller again]
# Tokenized=[Will definately order seller]
#  Original=[My phone recently suffered quite a bit of bumps and falls, which resulted in scratches.]
# Tokenized=[My phone recently suffered quite bit bumps falls , resulted scratches .]
#  Original=[I found this housing case to fit my Blackberry, and it is just like new.]
# Tokenized=[I found housing case fit Blackberry , like new .]
#  Original=[I have a beautiful phone again.]
# Tokenized=[I beautiful phone .]
#  Original=[The only thing that I would suggest for improving an already great productis; Please put instructions on how to install the new housing case in the package.]
# Tokenized=[The thing I would suggest improving already great productis ; Please put instructions install new housing case package .]
#  Original=[We had to google how to, and then review a video on YouTube on "How To."]
# Tokenized=[We google , review video YouTube `` How To . '']
#  Original=[I had my blackberryt in my pocket and my trousers were on the floor I stepped on it and broke the outside glass (plastic) I fretted about it and found the repalcement would be a new blackberry, I checked amazon and found a repalcement skin in the color of my choice GreatGoing Amazon]
# Tokenized=[I blackberryt pocket trousers floor I stepped broke outside glass ( plastic ) I fretted found repalcement would new blackberry , I checked amazon found repalcement skin color choice GreatGoing Amazon]
#  Original=[Seller does not have a video on their site with instructions for replacing the cover.]
# Tokenized=[Seller video site instructions replacing cover .]
#  Original=[I did find some useful videos on [...] though.]
# Tokenized=[I find useful videos [ ... ] though .]
#  Original=[My original housing was gray.]
# Tokenized=[My original housing gray .]
#  Original=[The scratches on the red housing are much more noticeable.]
# Tokenized=[The scratches red housing much noticeable .]
#  Original=[Item was easy to install & seller provided tools necessary to remove internal screws.]
# Tokenized=[Item easy install & seller provided tools necessary remove internal screws .]
#  Original=[i bought this phone case for my cousin who just got a new iPhone.]
# Tokenized=[bought phone case cousin got new iPhone .]
#  Original=[i was super excited because he loves memes and to be a troll so i thought this gift was perfect.]
# Tokenized=[super excited loves memes troll thought gift perfect .]
#  Original=[i literally just got the package not 2 minutes ago and im already pissed off.]
# Tokenized=[literally got package 2 minutes ago im already pissed .]
#  Original=[the case itself looks cheap but seems firm enough to last so the $9.95 price didn't seem to bad but then i got charged $11.24 for shipping!!]
# Tokenized=[case looks cheap seems firm enough last $ 9.95 price n't seem bad got charged $ 11.24 shipping ! !]
#  Original=[when i opened the  bubble envelope it came in i was super let down.]
# Tokenized=[opened bubble envelope came super let .]
#  Original=[the phone isn't even in warping or in a bag or anything!!??]
# Tokenized=[phone n't even warping bag anything ! ! ? ?]
#  Original=[it was just thrown in the bubble envelope and sealed and that's it.]
# Tokenized=[thrown bubble envelope sealed 's .]
#  Original=[I've ordered phones on Amazon before and they came in the same type of envelope but they always had some warping or a plastic wrap on it to at least look a little professional.]
# Tokenized=[I 've ordered phones Amazon came type envelope always warping plastic wrap least look little professional .]
#  Original=[the phone case itself isn't to bad but isn't great.]
# Tokenized=[phone case n't bad n't great .]
#  Original=[the way the packaged the case and showed themselves as a company is sad.]
# Tokenized=[way packaged case showed company sad .]
#  Original=[they just threw it in a envelope and sent it off and changed me more the the price of the case for shipping.]
# Tokenized=[threw envelope sent changed price case shipping .]
#  Original=[DONT BUY!!!!]
# Tokenized=[DONT BUY ! ! ! !]
#  Original=[i hope SawgNation sees this.]
# Tokenized=[hope SawgNation sees .]
#  Original=[this is ridiculous and i hope to be refunded for the &#34;shipping&#34; they did &#62;:(]
# Tokenized=[ridiculous hope refunded & # 34 ; shipping & # 34 ; & # 62 ; : (]
#  Original=[It was exquisite and now I walk about the world with my memephone like a boss who can and will accept any challenge]
# Tokenized=[It exquisite I walk world memephone like boss accept challenge]
#  Original=[It definitely met my expectations, I am very satisfied with the product.]
# Tokenized=[It definitely met expectations , I satisfied product .]
#  Original=[I'm now able to charge my phone a lot quicker.]
# Tokenized=[I 'm able charge phone lot quicker .]
#  Original=[It is a great handset, all my friends loved it.]
# Tokenized=[It great handset , friends loved .]
#  Original=[it works fine, this is the one I would recommend.]
# Tokenized=[works fine , one I would recommend .]
#  Original=[This is a very pretty bracelet.]
# Tokenized=[This pretty bracelet .]
#  Original=[Very sweet and very feminine.]
# Tokenized=[Very sweet feminine .]
#  Original=[Perfect for any occasion.]
# Tokenized=[Perfect occasion .]
#  Original=[I just adore this piece of jewelry.]
# Tokenized=[I adore piece jewelry .]
#  Original=[Thanks Amazon!!]
# Tokenized=[Thanks Amazon ! !]
#  Original=[:)]
# Tokenized=[: )]
#  Original=[Often I need to have to revamp my GPS.]
# Tokenized=[Often I need revamp GPS .]
#  Original=[This little gem does the job for me where ever I go.]
# Tokenized=[This little gem job ever I go .]
#  Original=[Couldn't be without it.]
# Tokenized=[Could n't without .]
#  Original=[this is a charger for a phone it has a micro usb plug not the Sony Vaio plug for the tap 11]
# Tokenized=[charger phone micro usb plug Sony Vaio plug tap 11]
#  Original=[Works great i watch netflix from cellphone to tv while im on breaks out here over the road truck driving]
# Tokenized=[Works great watch netflix cellphone tv im breaks road truck driving]
#  Original=[I bought this to play movies on my tv from my phone.]
# Tokenized=[I bought play movies tv phone .]
#  Original=[It was very easy to set up and works great!]
# Tokenized=[It easy set works great !]
#  Original=[It also allows me to charge my phone at the same time (although it is a slow charge).]
# Tokenized=[It also allows charge phone time ( although slow charge ) .]
#  Original=[I hooked this slimport up to my hdmi adapter and to my phone and started controlling the tv through my phone with no extra steps it is really an excellent device.]
# Tokenized=[I hooked slimport hdmi adapter phone started controlling tv phone extra steps really excellent device .]
#  Original=[I especially love that there is a charger hook up on the slim port so you can continue controlling the tv while charging your phone.]
# Tokenized=[I especially love charger hook slim port continue controlling tv charging phone .]
#  Original=[Bought this for use in a vehicle and it works!]
# Tokenized=[Bought use vehicle works !]
#  Original=[And it works fast, but I also bought a new charger that would handle 2+ amps of charging, that is one thing that is needed to charge FAST!!]
# Tokenized=[And works fast , I also bought new charger would handle 2+ amps charging , one thing needed charge FAST ! !]
#  Original=[!]
# Tokenized=[!]
#  Original=[I haven't had it very long and this past week while on vacation, it failed to work any longer.]
# Tokenized=[I n't long past week vacation , failed work longer .]
#  Original=[Unhappy buyer!]
# Tokenized=[Unhappy buyer !]
#  Original=[I ordered this product so I could stream movies from my Nexus tablet and my Nexus phone, it only works on my phone, so I am not giving it a 5 star right now.]
# Tokenized=[I ordered product I could stream movies Nexus tablet Nexus phone , works phone , I giving 5 star right .]
#  Original=[I just got it and am still seeing if I could get it to work on my tablet.]
# Tokenized=[I got still seeing I could get work tablet .]
#  Original=[I am happy though that it works on my phone, so thats good for me right now.]
# Tokenized=[I happy though works phone , thats good right .]
#  Original=[use this charger as a backup works great doesn't take long for the tablet to charge.]
# Tokenized=[use charger backup works great n't take long tablet charge .]
#  Original=[i would recommend this charger as a backup for when your're traveling.]
# Tokenized=[would recommend charger backup 're traveling .]
#  Original=[Works great.]
# Tokenized=[Works great .]
#  Original=[Just have to make sure the battery is charged before long use.]
# Tokenized=[Just make sure battery charged long use .]
#  Original=[Easy to use and battery inside will charge phone from dead with out sun light.]
# Tokenized=[Easy use battery inside charge phone dead sun light .]
#  Original=[It keeps showing like I'm connected to my computer and is not charging.]
# Tokenized=[It keeps showing like I 'm connected computer charging .]
#  Original=[The light comes on but its not working the way my other one did.]
# Tokenized=[The light comes working way one .]
#  Original=[This is a micro usb charger.]
# Tokenized=[This micro usb charger .]
#  Original=[No plug for VAIO, as I might have assumed from the title.Shipping on this item was very slow and was by USPSDon't buy one]
# Tokenized=[No plug VAIO , I might assumed title.Shipping item slow USPSDo n't buy one]
#  Original=[The Tap-11 requires a unique 19 volt power supply and connector.]
# Tokenized=[The Tap-11 requires unique 19 volt power supply connector .]
#  Original=[This power supply will NOT work with a Tap-11]
# Tokenized=[This power supply NOT work Tap-11]
#  Original=[That was not the charger I ordered for my tablet]
# Tokenized=[That charger I ordered tablet]
#  Original=[Is not compatible to charge the Tablet Sony Vaio Tap 11 - This Tablet has another AC adapter!]
# Tokenized=[Is compatible charge Tablet Sony Vaio Tap 11 - This Tablet another AC adapter !]
#  Original=[Please try to connect to charge your sony tap 11 and tell me if you can do it!]
# Tokenized=[Please try connect charge sony tap 11 tell !]
#  Original=[I have lost my money in this product!]
# Tokenized=[I lost money product !]
#  Original=[Very expensive and not real!!]
# Tokenized=[Very expensive real ! !]
#  Original=[!]
# Tokenized=[!]
#  Original=[This product never charged up in direct sun.It did charge from the wall.It did not charge my Kindle---it ran out after charging the Kindle about 1% !!]
# Tokenized=[This product never charged direct sun.It charge wall.It charge Kindle -- -it ran charging Kindle 1 % ! !]
#  Original=[!]
# Tokenized=[!]
#  Original=[This is advertised for the Transformer TF300, but since that device does not even have a micro-USB port and does not have the USB host built into the device, it will never work.]
# Tokenized=[This advertised Transformer TF300 , since device even micro-USB port USB host built device , never work .]
#  Original=[This thing worked for allof two minutes TOTAL!]
# Tokenized=[This thing worked allof two minutes TOTAL !]
#  Original=[$40 bucks wasted.]
# Tokenized=[$ 40 bucks wasted .]
#  Original=[This is the second cord I've purchased for viewing my phone on my television and this is the worst.]
# Tokenized=[This second cord I 've purchased viewing phone television worst .]
#  Original=[Really just about had it with Amazon.]
# Tokenized=[Really Amazon .]
#  Original=[I've had it with internet purchasing all together.]
# Tokenized=[I 've internet purchasing together .]
#  Original=[Just cant replace old school returns and face to face sellers.UPDATE would like to add that since the 1st posting Amazon has totally taken care of me on this and I can't explain how blown away I am by that.]
# Tokenized=[Just cant replace old school returns face face sellers.UPDATE would like add since 1st posting Amazon totally taken care I ca n't explain blown away I .]
#  Original=[I cannot say the same for the seller uhq tech.]
# Tokenized=[I say seller uhq tech .]
#  Original=[All emails were rude, sarcastic and completely un helpful.]
# Tokenized=[All emails rude , sarcastic completely un helpful .]
#  Original=[P.s.]
# Tokenized=[P.s .]
#  Original=[plugging in external power doesn't make this thing work either.]
# Tokenized=[plugging external power n't make thing work either .]
#  Original=[Now you can charge your Note 3 and access data at the same time!]
# Tokenized=[Now charge Note 3 access data time !]
#  Original=[My favorite feature of this device is that I can plug in a USB storage device and access those files be it media or data.]
# Tokenized=[My favorite feature device I plug USB storage device access files media data .]
#  Original=[I have seen youtube videos of the device connecting to a USB hub and running a myriad of different devices.]
# Tokenized=[I seen youtube videos device connecting USB hub running myriad different devices .]
#  Original=[Just make sure that those devices are compatible with your Note 3.]
# Tokenized=[Just make sure devices compatible Note 3 .]
#  Original=[I'm not super tech savvy but I would think the possibilities are nearly endless especially for the mobile warriors.]
# Tokenized=[I 'm super tech savvy I would think possibilities nearly endless especially mobile warriors .]
#  Original=[I will probably never access the full potential of the Note 3 but just being able to plug into USB devices is a handy feature to have.]
# Tokenized=[I probably never access full potential Note 3 able plug USB devices handy feature .]
#  Original=[Does not work with Dell Venue 8 Pro at all;  the seller replaced it with another one;  and it was the same;  THEY DON'T WORK;]
# Tokenized=[Does work Dell Venue 8 Pro ; seller replaced another one ; ; THEY DO N'T WORK ;]
#  Original=[Works fine as an OTG cable.]
# Tokenized=[Works fine OTG cable .]
#  Original=[Will NOT allow you to charge your tablet and use the USB at the same time.]
# Tokenized=[Will NOT allow charge tablet use USB time .]
#  Original=[Nope.]
# Tokenized=[Nope .]
#  Original=[Has a flat base that covers the analogue stick hole so nothing can get in there.]
# Tokenized=[Has flat base covers analogue stick hole nothing get .]
#  Original=[Other than that it's pretty basic plastic joystick.]
# Tokenized=[Other 's pretty basic plastic joystick .]
#  Original=[This hello kitty case is cute and I really do like it, but its silicone.]
# Tokenized=[This hello kitty case cute I really like , silicone .]
#  Original=[Its not hard.]
# Tokenized=[Its hard .]
#  Original=[That's the only thing that I didn't like.]
# Tokenized=[That 's thing I n't like .]
#  Original=[I was expecting a hard case.]
# Tokenized=[I expecting hard case .]
#  Original=[As a HUGE Hello Kitty fan, I absolutely LOVE this case.]
# Tokenized=[As HUGE Hello Kitty fan , I absolutely LOVE case .]
#  Original=[Just makes me love my iphone 4s even more :)]
# Tokenized=[Just makes love iphone 4s even : )]
#  Original=[It was very pretty when I first got it !]
# Tokenized=[It pretty I first got !]
#  Original=[After about a day it two the pink bow fell off !]
# Tokenized=[After day two pink bow fell !]
#  Original=[What a waste]
# Tokenized=[What waste]
#  Original=[Ordered this case for my sister, who is a fanatic of Hello Kitty!!!]
# Tokenized=[Ordered case sister , fanatic Hello Kitty ! ! !]
#  Original=[Just what we wanted, came sooner than we thought it would.]
# Tokenized=[Just wanted , came sooner thought would .]
#  Original=[Will be ordering more being that I have more family members who are Hello Kitty fans as well....great stocking stuffers]
# Tokenized=[Will ordering I family members Hello Kitty fans well ... .great stocking stuffers]
#  Original=[I love my case, I think it is the the cutest thing ever.]
# Tokenized=[I love case , I think cutest thing ever .]
#  Original=[I can always find it in my purse & I have gotten a few compliments regarding it.]
# Tokenized=[I always find purse & I gotten compliments regarding .]
#  Original=[Case is very durable, be careful when wearing w/jeans.]
# Tokenized=[Case durable , careful wearing w/jeans .]
#  Original=[I sort of messed mine up, the color faded onto the case but it's still cute.]
# Tokenized=[I sort messed mine , color faded onto case 's still cute .]
#  Original=[Delivery was very quick.]
# Tokenized=[Delivery quick .]
#  Original=[I also like the fact that they sent me a screen protector too!]
# Tokenized=[I also like fact sent screen protector !]
#  Original=[This was a good item came fast was wrapped good just wish it was more durable it broke on the first drop but that's not the sellers fault]
# Tokenized=[This good item came fast wrapped good wish durable broke first drop 's sellers fault]
#  Original=[I gave it 4 stars because it is a really neat case but unfortunately it provides no protection.]
# Tokenized=[I gave 4 stars really neat case unfortunately provides protection .]
#  Original=[Get this if you like the style and if you are one of the types that go through all extremes to keep something nice and protected.]
# Tokenized=[Get like style one types go extremes keep something nice protected .]
#  Original=[I love it personally because I have a newer Camaro and this matches my car and color.]
# Tokenized=[I love personally I newer Camaro matches car color .]
#  Original=[I also have not seen anyone else with this cover and many people ask me about it.]
# Tokenized=[I also seen anyone else cover many people ask .]
#  Original=[Beware though, kids might try to play with it like a car, and as stated, this provides pretty much no protection so be wary.I also got the case in great shape and had no problems with the shipping.]
# Tokenized=[Beware though , kids might try play like car , stated , provides pretty much protection wary.I also got case great shape problems shipping .]
#  Original=[It looks sharp, but it doesn't fit too well in the area of the volume buttons, making it hard to turn down volume, especially since it really bulges out in the area.]
# Tokenized=[It looks sharp , n't fit well area volume buttons , making hard turn volume , especially since really bulges area .]
#  Original=[Love my case.]
# Tokenized=[Love case .]
#  Original=[Looks great!!]
# Tokenized=[Looks great ! !]
#  Original=[Came fast.]
# Tokenized=[Came fast .]
#  Original=[Thanks a ton.]
# Tokenized=[Thanks ton .]
#  Original=[Feels really solid and fits perfect.]
# Tokenized=[Feels really solid fits perfect .]
#  Original=[I do not know what else to say about it but everytime I click submit it tells me to say more.]
# Tokenized=[I know else say everytime I click submit tells say .]
#  Original=[There that shoul be enough words geeze, its a phone case not a car.]
# Tokenized=[There shoul enough words geeze , phone case car .]
#  Original=[These are adorable and stick to anything.]
# Tokenized=[These adorable stick anything .]
#  Original=[But be careful, they really stick, I haven't found a way to get mine off the button yet.]
# Tokenized=[But careful , really stick , I n't found way get mine button yet .]
#  Original=[It's cute and fun...it has also gives me support when pushing the home button...I'm very happy Will purchase again and I recommend this item for anyone who love sponge-bob]
# Tokenized=[It 's cute fun ... also gives support pushing home button ... I 'm happy Will purchase I recommend item anyone love sponge-bob]
#  Original=[I was pleasantly surprised, the item came before its scheduled time, I really like the packaging of the case.]
# Tokenized=[I pleasantly surprised , item came scheduled time , I really like packaging case .]
#  Original=[The screen protectors fit perfectly as well as the case.Fantastic, really pleased with this purchase]
# Tokenized=[The screen protectors fit perfectly well case.Fantastic , really pleased purchase]
#  Original=[Catches a lot of attention from the kids - they think they can drive it around the table top - &#60;3]
# Tokenized=[Catches lot attention kids - think drive around table top - & # 60 ; 3]
#  Original=[Two minutes after putting this case on it broke!!!!]
# Tokenized=[Two minutes putting case broke ! ! ! !]
#  Original=[The next my husband gets home from work and there are already scratches all over it!]
# Tokenized=[The next husband gets home work already scratches !]
#  Original=[I was not happy with it.]
# Tokenized=[I happy .]
#  Original=[From what it looked like I thought it was suppose to protect the phone!]
# Tokenized=[From looked like I thought suppose protect phone !]
#  Original=[Good to see that I bought the iPhone4 shell, but not particularly put something perfect, I feel a bit small, crowded up.]
# Tokenized=[Good see I bought iPhone4 shell , particularly put something perfect , I feel bit small , crowded .]
#  Original=[I'll admit that I wasn't expecting this case to be as good as it is!]
# Tokenized=[I 'll admit I n't expecting case good !]
#  Original=[I've had it for almost two weeks and I bought it more for fashion than function, but it's actually pretty great.]
# Tokenized=[I 've almost two weeks I bought fashion function , 's actually pretty great .]
#  Original=[It's made of a flexible plastic that is easy to put on and take off, but sturdy enough that I'm not afraid of damage occurring to my phone or to the case itself while it's in my purse.]
# Tokenized=[It 's made flexible plastic easy put take , sturdy enough I 'm afraid damage occurring phone case 's purse .]
#  Original=[The paint is part of the plastic, not painted on the surface so the face and body should last for a while.]
# Tokenized=[The paint part plastic , painted surface face body last .]
#  Original=[Overall, I would recommend this case to another Rilakkuma fan.]
# Tokenized=[Overall , I would recommend case another Rilakkuma fan .]
#  Original=[First of all, I ordered the bear but I got a cat one in the mail instead.]
# Tokenized=[First , I ordered bear I got cat one mail instead .]
#  Original=[Super disappointed.]
# Tokenized=[Super disappointed .]
#  Original=[Second, The quality sucks.]
# Tokenized=[Second , The quality sucks .]
#  Original=[Really just not worth it in my opinion.]
# Tokenized=[Really worth opinion .]
#  Original=[It's also really bulky and made my phone feel huge.]
# Tokenized=[It 's also really bulky made phone feel huge .]
#  Original=[i lov it!]
# Tokenized=[lov !]
#  Original=[it is such a cute case~ it is soft~ the only thing is that i ordered the cat with white eyes not black eyes... but it actually doesnt matter~ the case is in great quality after all!]
# Tokenized=[cute case~ soft~ thing ordered cat white eyes black eyes ... actually doesnt matter~ case great quality !]
#  Original=[Love the clarity of the image, the lightweight aspect of the case and the overall durability of the product.]
# Tokenized=[Love clarity image , lightweight aspect case overall durability product .]
#  Original=[For Smurf fans everywhere!]
# Tokenized=[For Smurf fans everywhere !]
#  Original=[I absolutely loved this case.]
# Tokenized=[I absolutely loved case .]
#  Original=[It lasted me for 7+ months till it finally had too much and started falling apart.]
# Tokenized=[It lasted 7+ months till finally much started falling apart .]
#  Original=[I would definitely recommend this case to every hello kitty fan out there(:]
# Tokenized=[I would definitely recommend case every hello kitty fan ( :]
#  Original=[i bought this for my friend for christmas (2012) and to this day still uses it.]
# Tokenized=[bought friend christmas ( 2012 ) day still uses .]
#  Original=[it's super cute, the picture hasn't come off, and she always gets compliments on it.]
# Tokenized=['s super cute , picture n't come , always gets compliments .]
#  Original=[Bought this and it came in the mail relatively quick!]
# Tokenized=[Bought came mail relatively quick !]
#  Original=[It's super cute and girly, and I get compliments all of the time!]
# Tokenized=[It 's super cute girly , I get compliments time !]
#  Original=[For as rough as my phnoe is treated, it does a pretty good job of protecting it!]
# Tokenized=[For rough phnoe treated , pretty good job protecting !]
#  Original=[Thank you]
# Tokenized=[Thank]
# 100
#  Original=[Love it!]
# Tokenized=[Love !]
#  Original=[My best friend liked it so much i gave it to her, now iim about to buy another One (:]
# Tokenized=[My best friend liked much gave , iim buy another One ( :]
#  Original=[I got this for my girlfriend and it makes her IPhone look brand new.]
# Tokenized=[I got girlfriend makes IPhone look brand new .]
#  Original=[She likes pandas but it's difficult to find something like this for a good price.]
# Tokenized=[She likes pandas 's difficult find something like good price .]
#  Original=[I'm very satisfied.]
# Tokenized=[I 'm satisfied .]
#  Original=[The addition of a screen protector was a nice touch too.]
# Tokenized=[The addition screen protector nice touch .]
#  Original=[I really thought the panda is cute but the first time I tried to take the case off it cracked.]
# Tokenized=[I really thought panda cute first time I tried take case cracked .]
#  Original=[The picture shows this like light blue color case, what I received was this turquoise see through cover.]
# Tokenized=[The picture shows like light blue color case , I received turquoise see cover .]
#  Original=[Though its not the right color I still love it because its still adorable!]
# Tokenized=[Though right color I still love still adorable !]
#  Original=[The product came within two weeks the right estimation, happy with my case!]
# Tokenized=[The product came within two weeks right estimation , happy case !]
#  Original=[I also got the screen protector that came with it !]
# Tokenized=[I also got screen protector came !]
#  Original=[I received my product in less than four business days and I'm extremely satisfied.]
# Tokenized=[I received product less four business days I 'm extremely satisfied .]
#  Original=[The Hello Kitty button fits perfectly over the home screen and is easy to access!!!]
# Tokenized=[The Hello Kitty button fits perfectly home screen easy access ! ! !]
#  Original=[Very happy shopper!!!]
# Tokenized=[Very happy shopper ! ! !]
#  Original=[!]
# Tokenized=[!]
#  Original=[I love Hello Kitty, so I love these lil home buttons!]
# Tokenized=[I love Hello Kitty , I love lil home buttons !]
#  Original=[I love anything that adds a lil style to my devices and these do just that.]
# Tokenized=[I love anything adds lil style devices .]
#  Original=[The shipping was fast and they were just as described by the seller.]
# Tokenized=[The shipping fast described seller .]
#  Original=[Thanks]
# Tokenized=[Thanks]
#  Original=[not only are these things super cute, but they stay on forever!!]
# Tokenized=[things super cute , stay forever ! !]
#  Original=[I had one on for months!!]
# Tokenized=[I one months ! !]
#  Original=[I received soooo many  compliments and aww's]
# Tokenized=[I received soooo many compliments aww 's]
#  Original=[I love this iPhone cover.]
# Tokenized=[I love iPhone cover .]
#  Original=[It fits my iPhone perfectly and is sturdy enough to stand up to my having dropped the phone more than a couple times.]
# Tokenized=[It fits iPhone perfectly sturdy enough stand dropped phone couple times .]
#  Original=[The colors have stayed true for the several yearls I've had the case, and it helps me to find my phone in my black purseSponge Bob Squarepants Bubbles Blowing Hard Case Cover Iphone 4/4s because of the bright colors and charming picture.]
# Tokenized=[The colors stayed true several yearls I 've case , helps find phone black purseSponge Bob Squarepants Bubbles Blowing Hard Case Cover Iphone 4/4s bright colors charming picture .]
# ...
#  Original=[The one and only thing I didn't like about this item was it made my phone feel heavier.]
# Tokenized=[The one thing I n't like item made phone feel heavier .]
#  Original=[Why I don't know but it did.]
# Tokenized=[Why I n't know .]
#  Original=[It's also a little tricky to remove from your device.]
# Tokenized=[It 's also little tricky remove device .]
#  Original=[At first I received the wrong item but the customer service was great.]
# Tokenized=[At first I received wrong item customer service great .]
#  Original=[They sent me the correct product very fast and credited me for my inconvienience.]
# Tokenized=[They sent correct product fast credited inconvienience .]
#  Original=[Thanks.]
# Tokenized=[Thanks .]
#  Original=[Great Job A+.]
# Tokenized=[Great Job A+ .]
#  Original=[This is a great case...]
# Tokenized=[This great case ...]
#  Original=[It fit my phone perfectly and I still use it from time to time.]
# Tokenized=[It fit phone perfectly I still use time time .]
#  Original=[Would recommend]
# Tokenized=[Would recommend]
#  Original=[It's cute just cracks easy and hard to take off without throwing your phone against the wall!]
# Tokenized=[It 's cute cracks easy hard take without throwing phone wall !]
#  Original=[But great price]
# Tokenized=[But great price]
#  Original=[I have had this one on my phone since I purchased it and love the deco art style of it.]
# Tokenized=[I one phone since I purchased love deco art style .]
#  Original=[Saves my phone from damage.]
# Tokenized=[Saves phone damage .]
#  Original=[This case arrived on time, and it looks the same way it does in the picture.]
# Tokenized=[This case arrived time , looks way picture .]
#  Original=[It will stay on the phone, and protects it well.]
# Tokenized=[It stay phone , protects well .]
#  Original=[Realy like this!!]
# Tokenized=[Realy like ! !]
#  Original=[Very colorful as I had hoped.]
# Tokenized=[Very colorful I hoped .]
#  Original=[It has a matte finish that makes it very easy to grip/hold without being slippery.]
# Tokenized=[It matte finish makes easy grip/hold without slippery .]
#  Original=[Great choice!]
# Tokenized=[Great choice !]
#  Original=[My husband wore out his OtterBox and I gave him mine.]
# Tokenized=[My husband wore OtterBox I gave mine .]
#  Original=[This case has worked great for me and I get compliments all the time!]
# Tokenized=[This case worked great I get compliments time !]
#  Original=[I recently purchased and received this case for my HTC EVO.]
# Tokenized=[I recently purchased received case HTC EVO .]
#  Original=[After reading all of the bad reviews on this one, I still really liked the design so I figured I'd go ahead and order it, and also order another rubberized snap-on case, different design.]
# Tokenized=[After reading bad reviews one , I still really liked design I figured I 'd go ahead order , also order another rubberized snap-on case , different design .]
#  Original=[When I got the cases, they were both beautiful, especially this one.]
# Tokenized=[When I got cases , beautiful , especially one .]
#  Original=[The design looks exactly like in the picture and it wasn't broken like a lot of people are saying.]
# Tokenized=[The design looks exactly like picture n't broken like lot people saying .]
#  Original=[It was in perfect condition and also fits the phone perfectly.]
# Tokenized=[It perfect condition also fits phone perfectly .]
#  Original=[But the case is not rubberized (neither one of them).]
# Tokenized=[But case rubberized ( neither one ) .]
#  Original=[In fact, there's barely much plastic to it at all....one drop and this case would be history.]
# Tokenized=[In fact , 's barely much plastic ... .one drop case would history .]
#  Original=[Would it protect the phone?]
# Tokenized=[Would protect phone ?]
#  Original=[Maybe.]
# Tokenized=[Maybe .]
#  Original=[But no rubber at all...I was hoping to get a plastic case with a rubber coating, to provide some type of shock resistance in the event of a drop.]
# Tokenized=[But rubber ... I hoping get plastic case rubber coating , provide type shock resistance event drop .]
#  Original=[But no can do.]
# Tokenized=[But .]
#  Original=[The title also says something about a faceplate?]
# Tokenized=[The title also says something faceplate ?]
#  Original=[I don't know what that means but there was no "faceplate", just a case.]
# Tokenized=[I n't know means `` faceplate '' , case .]
#  Original=[But hey you get what you pay for.]
# Tokenized=[But hey get pay .]
#  Original=[Rubberized hard cases are expensive, so it's silly to think you would find one for less than $5.00.]
# Tokenized=[Rubberized hard cases expensive , 's silly think would find one less $ 5.00 .]
#  Original=[Really pretty case but the colors on this Evo phone case faded really quick especially on the back side of the cover...]
# Tokenized=[Really pretty case colors Evo phone case faded really quick especially back side cover ...]
#  Original=[Received this item very quickly.]
# Tokenized=[Received item quickly .]
#  Original=[The design is even more vivid than expected.]
# Tokenized=[The design even vivid expected .]
#  Original=[The cover is soft (rubberized) but durable.]
# Tokenized=[The cover soft ( rubberized ) durable .]
#  Original=[I have received many compliments.]
# Tokenized=[I received many compliments .]
#  Original=[It was an excellent buy!]
# Tokenized=[It excellent buy !]
#  Original=[I would recommend this to anyone wanting a "good look" for their phone.]
# Tokenized=[I would recommend anyone wanting `` good look '' phone .]
#  Original=[I ordered this along with several other HTC Evo cases.]
# Tokenized=[I ordered along several HTC Evo cases .]
#  Original=[It's as nice as any other phone case I've bought and paid $20 or more for.]
# Tokenized=[It 's nice phone case I 've bought paid $ 20 .]
#  Original=[Once snapped on, it was near impossible to get off, but I think that was a good thing.]
# Tokenized=[Once snapped , near impossible get , I think good thing .]
#  Original=[I've had other cases that would pop off if I dropped them.]
# Tokenized=[I 've cases would pop I dropped .]
#  Original=[I would say this is worth every cent.]
# Tokenized=[I would say worth every cent .]
#  Original=[The design doesnt have all the purple like it shows in the picture but still love it, slim nice fit]
# Tokenized=[The design doesnt purple like shows picture still love , slim nice fit]
#  Original=[I drop my phone often and it has not broken at all.]
# Tokenized=[I drop phone often broken .]
#  Original=[this is a great case.]
# Tokenized=[great case .]
#  Original=[I recommend this to anyone.]
# Tokenized=[I recommend anyone .]
#  Original=[I found this on Amazon right after I paid $20.00 for a phone cover at the mall.]
# Tokenized=[I found Amazon right I paid $ 20.00 phone cover mall .]
#  Original=[I purchased 2 different covers and love both of them.]
# Tokenized=[I purchased 2 different covers love .]
#  Original=[They were a great buy for the money.]
# Tokenized=[They great buy money .]
#  Original=[Pretty, but not as bright and vivid as in the picture.]
# Tokenized=[Pretty , bright vivid picture .]
#  Original=[NOT protective at all, this is just for looks, happy meal toys come sturdier than this.]
# Tokenized=[NOT protective , looks , happy meal toys come sturdier .]
#  Original=[It will burst upon impact.]
# Tokenized=[It burst upon impact .]
#  Original=[With that being said...I am a girlie girl and I love having different colors and designs on my phone and that's what this is for.]
# Tokenized=[With said ... I girlie girl I love different colors designs phone 's .]
#  Original=[My mom & i had the same phone case.Im kind of hard on my phone.I try not to drop it but it seems to happen alot.My mom is very protective of her phone(she rarely drops it.]
# Tokenized=[My mom & phone case.Im kind hard phone.I try drop seems happen alot.My mom protective phone ( rarely drops .]
#  Original=[)But in this situation she had the case for a few weeks before it broke.It fell off of the desk & broke instantly.But i had it for a few months & dropped my phone a million times(falling on concrete & wooden floors w/o a crack on the case or phone)before it finally broke 2weeks ago(falling from the couch to the floor)So i think the life span on this case depends on how you handle your phone.]
# Tokenized=[) But situation case weeks broke.It fell desk & broke instantly.But months & dropped phone million times ( falling concrete & wooden floors w/o crack case phone ) finally broke 2weeks ago ( falling couch floor ) So think life span case depends handle phone .]
#  Original=[yes would recommend, fun design, little less strong than I would like but for the price, fun change, would buy again]
# Tokenized=[yes would recommend , fun design , little less strong I would like price , fun change , would buy]
#  Original=[I wanted to highly recommend this seller>I had a slight issue with the product, and they offered a complete refund without having to send the product back:) I fixed the case, so there was no need for the refund.]
# Tokenized=[I wanted highly recommend seller > I slight issue product , offered complete refund without send product back : ) I fixed case , need refund .]
#  Original=[Thanks for being an honest company!!!!!]
# Tokenized=[Thanks honest company ! ! ! ! !]
#  Original=[!]
# Tokenized=[!]
#  Original=[Its beautiful and sturdy but the paint chips easily and its a pain to open the case to take out the cellphone.]
# Tokenized=[Its beautiful sturdy paint chips easily pain open case take cellphone .]
#  Original=[The sleeve is pretty cool and avoids damage to the case, which is a plus.]
# Tokenized=[The sleeve pretty cool avoids damage case , plus .]
#  Original=[this cover makes an old phone look and feel new.]
# Tokenized=[cover makes old phone look feel new .]
#  Original=[I like that I can order covers for little money and snazzy up my phone.]
# Tokenized=[I like I order covers little money snazzy phone .]
#  Original=[I am very unhappy with the product.]
# Tokenized=[I unhappy product .]
#  Original=[I expected a rubber frame and the whole product is cheap plastic.]
# Tokenized=[I expected rubber frame whole product cheap plastic .]
#  Original=[Also, it does not fit my htc Evo 4g.]
# Tokenized=[Also , fit htc Evo 4g .]
#  Original=[Fortunately, I did not pay much, but I do not like losing any money at all.]
# Tokenized=[Fortunately , I pay much , I like losing money .]
#  Original=[Do not buy this if you have a Virgin Mobile htc Evo 4g with a 3D camera.]
# Tokenized=[Do buy Virgin Mobile htc Evo 4g 3D camera .]
#  Original=[The slots do not much.]
# Tokenized=[The slots much .]
#  Original=[When i recieved it the first time it was white with cute design and i loved it but after a while it got dirty and cracked so i ordered another one same color and design but the background came back as gray.... um not what i ordered.]
# Tokenized=[When recieved first time white cute design loved got dirty cracked ordered another one color design background came back gray ... . um ordered .]
#  Original=[cute but doesnt last long needs shiny film over to last longer.]
# Tokenized=[cute doesnt last long needs shiny film last longer .]
#  Original=[Upon ordering the Phone Case, I received it timely & when placing it on my phone, I had no problems snapping it together...I love the design on it.]
# Tokenized=[Upon ordering Phone Case , I received timely & placing phone , I problems snapping together ... I love design .]
#  Original=[When I ordered the same one previously, when receiving it, the background white color was more translucent, which I actually preferred.]
# Tokenized=[When I ordered one previously , receiving , background white color translucent , I actually preferred .]
#  Original=[~ winddancer57]
# Tokenized=[~ winddancer57]
#  Original=[These are cheap but worked great for my phone.]
# Tokenized=[These cheap worked great phone .]
#  Original=[I do drop it a lot.]
# Tokenized=[I drop lot .]
#  Original=[Some of these did break when I dropped my phone but at least my phone Is ok!]
# Tokenized=[Some break I dropped phone least phone Is ok !]
#  Original=[I have had my phone for about two years with the cover I purchased from sprint.]
# Tokenized=[I phone two years cover I purchased sprint .]
#  Original=[I have dropped my phone plenty of time through out this time and never had any problems.]
# Tokenized=[I dropped phone plenty time time never problems .]
#  Original=[I put this cover on my phone Thursday night, on Friday morning it fell off my bed, the cover fell off and my screen shattered.]
# Tokenized=[I put cover phone Thursday night , Friday morning fell bed , cover fell screen shattered .]
#  Original=[I just had to spend $100 for a replacement phone.]
# Tokenized=[I spend $ 100 replacement phone .]
#  Original=[This cover isn't rubberized as it says and the cover falls off way too easy.]
# Tokenized=[This cover n't rubberized says cover falls way easy .]
#  Original=[Fits nicely, I'm really enjoying the cover.]
# Tokenized=[Fits nicely , I 'm really enjoying cover .]
#  Original=[It is real nice and pretty.]
# Tokenized=[It real nice pretty .]
#  Original=[Recommended to everyone!]
# Tokenized=[Recommended everyone !]
#  Original=[;) A must buy item.]
# Tokenized=[; ) A must buy item .]
#  Original=[I LOVE this case!]
# Tokenized=[I LOVE case !]
#  Original=[I got it for my samsung galaxy s 4g (although this is for the vibrant) but it fit perfectly.]
# Tokenized=[I got samsung galaxy 4g ( although vibrant ) fit perfectly .]
#  Original=[I always get complimented on it.]
# Tokenized=[I always get complimented .]
#  Original=[My brother loves this case .]
# Tokenized=[My brother loves case .]
#  Original=[well built and beautiful .]
# Tokenized=[well built beautiful .]
#  Original=[I like it so far and will purchase other for gifts.]
# Tokenized=[I like far purchase gifts .]
#  Original=[The color of the case isn't as bright as the pic shows, its more of a duller color, but the case is good quality and fits good.]
# Tokenized=[The color case n't bright pic shows , duller color , case good quality fits good .]
#  Original=[Would buy from this seller again, Fast Shipping!]
# Tokenized=[Would buy seller , Fast Shipping !]
#  Original=[this is the second faceplate for my phone that i've gone through, and i've ordered two more already.]
# Tokenized=[second faceplate phone 've gone , 've ordered two already .]
#  Original=[the clips on there don't hold very well.]
# Tokenized=[clips n't hold well .]
#  Original=[if you are prone to dropping your phone, like i am, then one good drop and the top plate is broken for good.]
# Tokenized=[prone dropping phone , like , one good drop top plate broken good .]
#  Original=[so i can either keep buying new ones, or think about a new phone=)]
# Tokenized=[either keep buying new ones , think new phone= )]
#  Original=[this case lasted me all through the month of december :D its a really pretty color case too :) very sturdy]
# Tokenized=[case lasted month december : D really pretty color case : ) sturdy]
#  Original=[The case is pretty.Sadly though the packaging isn't original and after ordering one from another seller than went through in only a couple months I don't think I shall be ordering any more speck cases on amazon,The feel of the case isn't as sturdy as an original and the bottom part that covers the charging port already feels like it again won't last long before breaking.This may not be what you're looking for,]
# Tokenized=[The case pretty.Sadly though packaging n't original ordering one another seller went couple months I n't think I shall ordering speck cases amazon , The feel case n't sturdy original bottom part covers charging port already feels like wo n't last long breaking.This may 're looking ,]
# 1000
#  Original=[This case is extremely durable with the combined hardcase and softcase aspects.]
# Tokenized=[This case extremely durable combined hardcase softcase aspects .]
#  Original=[I have dropped my phone in it, and there was not any damage to my phone.]
# Tokenized=[I dropped phone , damage phone .]
#  Original=[It's snug, so it can be a little bit of a challenge to take off.]
# Tokenized=[It 's snug , little bit challenge take .]
#  Original=[Overall good product.]
# Tokenized=[Overall good product .]

# %% [markdown]
# **[Assignment 1]**
# Spend some time to go over the code and compare the sentences generated from the tokenization step with the original ones.

# %% [markdown]
# Next we'll compute the frequency count across all words in the collection:

# %%
import numpy as np
frequency_count = nltk.FreqDist(all_words)
words =np.array([word for word in frequency_count.keys()])
word_freq=np.array([word for word in frequency_count.values()])

# %% [markdown]
# We'll then sort words in the collection using their frequency count:

# %%
freq_sort = np.argsort(word_freq)[::-1]
word_freq_sort =word_freq[freq_sort]
words_sorted = words[freq_sort]

# %% [markdown]
# Print the sorted words and write them to a file:

# %%
output = open(review_file+".fc",'w')
rank=1
for object in words_sorted:
    output.write(object+"\t"+str(frequency_count[object])+"\n")
    if (rank<=100):
        print(object+"\t"+str(frequency_count[object]))
    rank+=1
output.close()
# Out:
# .	2465
# i	1535
# ,	1214
# !	592
# phone	501
# case	468
# n't	372
# it	320
# the	254
# one	247
# 's	235
# would	218
# great	209
# charge	192
# product	187
# like	186
# charger	166
# this	153
# time	152
# love	150
# get	147
# works	141
# car	139
# good	139
# )	137
# ...	136
# use	126
# well	122
# (	118
# really	111
# work	109
# got	106
# bought	101
# price	101
# charging	100
# iphone	98
# ;	98
# even	97
# &	94
# battery	92
# buy	91
# recommend	91
# also	86
# item	84
# little	81
# two	78
# nice	77
# usb	74
# cute	73
# fit	71
# much	71
# :	71
# 2	70
# 've	69
# long	67
# money	66
# still	66
# looks	64
# not	61
# #	60
# came	59
# 'm	59
# light	59
# better	58
# power	58
# thing	56
# my	56
# cover	55
# quality	55
# first	54
# could	54
# cheap	54
# button	53
# ordered	52
# port	52
# worth	52
# easy	51
# pretty	51
# fits	50
# way	49
# plugged	48
# made	48
# day	47
# fine	47
# glass	47
# working	47
# screen	47
# using	46
# ipad	46
# worked	46
# look	46
# design	45
# device	45
# received	45
# broke	45
# though	44
# 34	44
# back	43
# home	43
# very	42

# %% [markdown]
# **[Assignment 2]**
# Going over the sorted list you've shurley noticed that the tokenizer outputted many single characters, some of which are punctuation marks. In general single character tokens don't carry any useful information and therefore are filtered out.
# Revisit the tokenization code above and remove single character tokens by checking on the token length. Token length could be checked using the "len" method which we also cover in class.

# %% [markdown]
# **[Solution 2]**
# substitute the above expression for "sent_tok" with the following one:

# %%
 sent_tok = [word for word in sent_tok if word not in stopwords_list and len(word) >1]

# %% [markdown]
# During the lab session we also wrote code on how to read the frequency count file that we created earlier. Below is the code:

# %%
infile = open(review_file+".fc",'r')
rank=1
for line in infile.readlines():
    line=line.strip()
    elem = line.split("\t")
    if (rank<=100):
        print(elem[0]+"\t"+elem[1])
    rank+=1
infile.close()
# Out:
# .	2465
# i	1535
# ,	1214
# !	592
# phone	501
# case	468
# n't	372
# it	320
# the	254
# one	247
# 's	235
# would	218
# great	209
# charge	192
# product	187
# like	186
# charger	166
# this	153
# time	152
# love	150
# get	147
# works	141
# car	139
# good	139
# )	137
# ...	136
# use	126
# well	122
# (	118
# really	111
# work	109
# got	106
# bought	101
# price	101
# charging	100
# iphone	98
# ;	98
# even	97
# &	94
# battery	92
# buy	91
# recommend	91
# also	86
# item	84
# little	81
# two	78
# nice	77
# usb	74
# cute	73
# fit	71
# much	71
# :	71
# 2	70
# 've	69
# long	67
# money	66
# still	66
# looks	64
# not	61
# #	60
# came	59
# 'm	59
# light	59
# better	58
# power	58
# thing	56
# my	56
# cover	55
# quality	55
# first	54
# could	54
# cheap	54
# button	53
# ordered	52
# port	52
# worth	52
# easy	51
# pretty	51
# fits	50
# way	49
# plugged	48
# made	48
# day	47
# fine	47
# glass	47
# working	47
# screen	47
# using	46
# ipad	46
# worked	46
# look	46
# design	45
# device	45
# received	45
# broke	45
# though	44
# 34	44
# back	43
# home	43
# very	42

# %% [markdown]
# **[Assignment 3]**
# The default NLTK tokenizer utilizes conventions from the Penn Treebank corpus one of which is to separates contractions. Let's look at an example:

# %%
nltk.word_tokenize("I wouldn't")
# Out:
# ['I', 'would', "n't"]

# %% [markdown]
# An alternative to the Penn Treebank tokenizer is the PunktWordTokenizer which splits on the actual punctuation. Below is an example on how to utilize it:

# %%
import nltk.data
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
tokenizer.tokenize("wouldn't")
# Out:
# ["wouldn't"]

# %% [markdown]
# Tokenize the collection using this tokenizer.

# %% [markdown]
# **[Solution 3]**
# Load the new tokenizer:

# %%
import nltk.data 
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

# %% [markdown]
# and substitute the following expression:

# %%
sent_tok = nltk.word_tokenize(sentence)

# %% [markdown]
# with this one:

# %%
sent_tok = nltk.word_tokenize(sentence)

# %% [markdown]
# ### Stemming ###
# In the previous lecture we learned about stemming and we also did an overview of the two most common stemmers - the Porter and the Krovetz stemmers. We'll now use the Porter stemmer to stem our collection.

# %% [markdown]
# **[Assignment 4]**
# Revisit the tokenization code above and using the NLTK implementation of the Porter stemmer to stem the collection. You can instantiate the NLTK Porter stemmer using the following code:

# %%
from nltk.stem.porter import PorterStemmer
porter_stemmer = PorterStemmer()

# %% [markdown]
# To stem a word you would call the "stem" method. Below is an example:

# %%
porter_stemmer.stem("beautiful")
# Out:
# 'beauti'

# %% [markdown]
# **[Solution 4]**
# Load the PorterStemmer and substitute the above expression for "sent_tok" with the following one:

# %%
 sent_tok = [porter_stemmer.stem(word) for word in sent_tok if word not in stopwords_list]

# %% [markdown]
# ### Frequency Plot ###

# %% [markdown]
# **[Assignment 5]**
# Yesterday we went over some example of plotting data in python. In this assignment you are asked to plot the frequency count versus the rank. We already have the frequency count stored in the list "word_freq_sort". We are also providing you with a rank list. You should use log scale for both axis. Computing a log over an numpy array could be done with the "np.log" method.

# %% [markdown]
# **[Solution 5]**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn
# %matplotlib notebook

#generate an array of ranks:
rank= range(1,len(words_sorted)+1)
print (rank)
#generate an array of frequency counts:
freq = np.array(word_freq_sort)

fig = plt.figure()
#enter your solution here:
plt.plot(np.log(rank),np.log(freq))
#plt.plot(rank,pr)
plt.title('Frequency count vs. rank')
plt.xlabel('log(Rank)')
plt.ylabel('log(Frequency count)')
plt.show()
# Out:
# range(1, 3954)
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# **[Assignment 6 (Optional]**
# So far we've used 1000 product reviews. In the data folder there are also sets of 5k and 10k reviews. If time permits you should perform the same text statistics over these collections.
# In addition to this category reviews we've provided you with reviews (1k, 5k, and 10k) for 4 additional  categories:
# * Beauty
# * Clothing, Shoes and Jewelery
# * Digital Music
# * Tools and Home Improvement

# %% [markdown]
# **[Solution 6]**
