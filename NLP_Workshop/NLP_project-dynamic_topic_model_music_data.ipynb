# %% [markdown]
# # Dynamic Topic Models Project on Amazon music data
# # Soomin Cho, Blair Alexander

# %%
import logging
import os
from gensim import corpora, utils
from gensim.models.wrappers.dtmmodel import DtmModel
import numpy as np
import pandas as pd
import gzip
# Out:
# C:\Anaconda3\lib\site-packages\gensim\utils.py:860: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
def parse(path):
  g = gzip.open(path, 'rb')
  for l in g:
    yield eval(l)

def getDF(path):
  i = 0
  df = {}
  for d in parse(path):
    df[i] = d
    i += 1
  return pd.DataFrame.from_dict(df, orient='index')


review_file = "../../../data/amazon_reviews/dm/reviews_Digital_Music_h10k.json.gz"

df = getDF(review_file)
print (df['reviewText'])
# Out:
# 0       The anthemic title track begins &quot;The Memo...
# 1       Just when I thought Enya couldn't possibly get...
# 2       Nice CD for easy listening.  My husband and I ...
# 3       I really liked this CD, especially the differe...
# 4       Enya's richly chorded style has smitten me onc...
# 5       It's hard to believe "Memory of Trees" came ou...
# 6       I am an enya fan and like her cd's. on this cd...
# 7       I'm not a huge, know it all Enya fan.  But I d...
# 8       This is my very favorite Enya album to date. E...
# 9       I love, love love love love The Memory of Tree...
# 10      I only recently discovered this album by Enya,...
# 11      Ok, first off, Enya rocks.  If you don't know ...
# 12      A clasically-styled and introverted album, Mem...
# 13      Okay, so I'm spreading my #1 rating around.  &...
# 14      I never thought Enya would reach the sublime h...
# 15      Certainly of very good sound quality.  A coupl...
# 16      THE MEMORY OF TREES, combines esoteric grandeu...
# 17      I love Watermarket and Shepperd Moons but this...
# 18      This album was actually my first exposure to E...
# 19      This is the third review of an irish album I w...
# 20      In terms of simply flawless and beautiful musi...
# 21      This is my favorite Enya album, having to do m...
# 22      I've had this CD for years, and EVERY time I t...
# 23      Enya, despite being a successful recording art...
# 24      In Memory of Trees is yet another great effort...
# 25      This album is so hauntingly beautiful.  It rem...
# 26      Enya is such a wonderful artist, truly given a...
# 27      Who knows why I initially considered this to b...
# 28      Once in a while, I'll hear music that affects ...
# 29      Replacing lost albums, and this was one of the...
#                               ...
# 9970    I tracked this down after reading that Broadca...
# 9971    This was a seminal recording for me--my first ...
# 9972    Listening to this record, it is hard to ignore...
# 9973    Yes, we all know many of the big name late 60'...
# 9974    I thought it was a different artist . i clicke...
# 9975    I was accidentally exposed to this album in '7...
# 9976    I'd love the album if I could listen to it - I...
# 9977    I ordered the CD The United States of America ...
# 9978    This is definitely one of the great albums of ...
# 9979    this is a fine album released at the point whe...
# 9980    I don't have much to add more than the other r...
# 9981    In the sixties, when we escaped AM radio to fi...
# 9982    One of the most entertaining albums i've ever ...
# 9983    An intoxicating ride: well-known jazz tunes--S...
# 9984    This CD disappointed me because I expected muc...
# 9985    One of the greatests latinamerican jazz pianis...
# 9986    I first saw Michel Camilo performing in 2000 i...
# 9987    this guy is a true latin jazzman!!!  i just go...
# 9988    I love this CD and I'm really surprised there ...
# 9989    I highly recommend this album to those latin j...
# 9990    I am so pleased with this purchase. I have no ...
# 9991    Throughout the 90's most artists in R&B;,even ...
# 9992    Mint Condition lives up to its name!  They are...
# 9993    this is one of mint condition's best albums, t...
# 9994    I have bought this CD at least 5 times.  I lis...
# 9995    The title says it all. Each member gives a hun...
# 9996    Mint Condition has been putting out nothing bu...
# 9997    Lead singer Stokley Williams steals the show w...
# 9998    I am a true Minthead. Don't get me wrong. EVER...
# 9999    Another must have, good music. Some songs you ...
# Name: reviewText, Length: 10000, dtype: object

# %%
#see the first few rows of the dataset
df.head()

# %% [markdown]
# ## Data preprocessing (tokenize, remove stopwords, etc.)

# %%
import nltk
import string
from nltk.tree import Tree
stopwords_list = nltk.corpus.stopwords.words('english')
# Create a list for the tokenized sentences:
tok_sentences = list()
# Create a list for the tokenized reviews:
tok_reviews = list()
# Create a list for the sentence assigned POS tags:
pos_sentences = list()
# Create a translation table for removing the punctuation marks:
translator = str.maketrans('', '', string.punctuation)

all_words = list()
r_count = 0
for review in df['reviewText']:
    r_count += 1
    if (r_count % 1000 == 0):
        print(r_count)
    sentences = nltk.sent_tokenize(review)
    review_words= list()
    for sentence in sentences:
        sent_words = nltk.word_tokenize(sentence)
        sent_words_tok = [word.lower() for word in sent_words if word.lower() not in stopwords_list and word.isalpha()]
        tok_sentences.append(sent_words_tok) #the 
        for words in sent_words_tok:
            all_words.append(words)
            review_words.append(words)
    tok_reviews.append(review_words)
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000

# %%
#find out the date range of documents
years = [int(datetime.split()[2]) for datetime in df['reviewTime']]
years_argsort = np.argsort(years)

years_argsort
print(np.min(years))
print(np.max(years))
# Out:
# 1998
# 2014

# %%
#add reviews for each year to a dictionary
from collections import defaultdict
review_year_dict = defaultdict(list)
for year,review in zip(years,tok_reviews):
    review_year_dict[year].append(review)
# Out:
# [['anthemic', 'title', 'track', 'begins', 'quot', 'memory', 'trees', 'quot', 'fourth', 'cd', 'release', 'wordless', 'vocalizations', 'forceful', 'percussion', 'propel', 'song', 'stratosphere', 'quot', 'anywhere', 'quot', 'lead', 'single', 'cd', 'typical', 'earlier', 'fare', 'like', 'quot', 'orinoco', 'flow', 'quot', 'contains', 'magic', 'endearing', 'aspect', 'song', 'lyrics', 'roma', 'ryan', 'enya', 'long', 'time', 'lyricist', 'deserves', 'much', 'credit', 'amazing', 'lyrics', 'song', 'relax', 'fall', 'images', 'music', 'words', 'make', 'together', 'quot', 'pax', 'deorum', 'quot', 'like', 'hurricane', 'begins', 'ominously', 'like', 'calm', 'storm', 'builds', 'frighteningly', 'wicked', 'storm', 'immense', 'proportions', 'strings', 'drums', 'vocals', 'everywhere', 'middle', 'stops', 'small', 'lull', 'transpires', 'angels', 'come', 'sing', 'us', 'suddenly', 'wind', 'comes', 'back', 'thick', 'things', 'end', 'comes', 'suddenly', 'beginning', 'quot', 'athair', 'ar', 'neamh', 'quot', 'beautiful', 'ballad', 'lyrical', 'ballad', 'enya', 'produced', 'thus', 'far', 'song', 'enya', 'sounds', 'similar', 'sister', 'maire', 'brennan', 'lead', 'singer', 'group', 'clannad', 'quot', 'quot', 'another', 'solo', 'piano', 'piece', 'embodies', 'title', 'perfectly', 'picture', 'staring', 'wide', 'expanse', 'ocean', 'land', 'high', 'cliff', 'quot', 'china', 'roses', 'quot', 'song', 'love', 'song', 'past', 'feel', 'slow', 'moving', 'intensely', 'powerful', 'energy', 'undercurrent', 'song', 'beautiful', 'synthesized', 'sounds', 'add', 'atmosphere', 'quot', 'hope', 'place', 'quot', 'sounds', 'melancholy', 'like', 'someone', 'given', 'hope', 'enya', 'trying', 'tell', 'late', 'never', 'late', 'love', 'hope', 'place', 'soul', 'sweet', 'ballad', 'simplistic', 'arrangement', 'quot', 'moon', 'quot', 'another', 'instrumental', 'track', 'embodies', 'title', 'perfectly', 'sparkling', 'synthesizers', 'melodies', 'bring', 'mind', 'late', 'evening', 'tea', 'ceremony', 'underneath', 'bright', 'full', 'moon', 'late', 'summer', 'eve', 'quot', 'gold', 'quot', 'soft', 'waltz', 'lament', 'something', 'lost', 'gone', 'quot', 'la', 'sonadora', 'quot', 'enya', 'song', 'written', 'spanish', 'includes', 'unusual', 'effective', 'chord', 'changes', 'song', 'relax', 'quot', 'way', 'home', 'quot', 'starts', 'slow', 'organ', 'introduction', 'moves', 'complex', 'bassline', 'enya', 'travels', 'journey', 'home', 'seems', 'mind', 'walks', 'listening', 'song', 'stop', 'bridge', 'sweet', 'flutes', 'massage', 'tired', 'mind', 'fabulous', 'way', 'end', 'fabulous', 'cd'], ['enya', 'richly', 'chorded', 'style', 'smitten', 'little', 'bit', 'gregorian', 'lot', 'celtic', 'combined', 'soft', 'well', 'crafted', 'execution', 'gives', 'us', 'cd', 'anyone', 'enjoy', 'relax', 'enya', 'performs', 'instruments', 'vocals', 'album', 'vocal', 'style', 'willowy', 'sweet', 'blends', 'synthesizer', 'piano', 'accompaniment', 'great', 'quot', 'hot', 'tub', 'quot', 'massage', 'music', 'lucky', 'tub', 'masseuse', 'available', 'try', 'recliner', 'glass', 'wine', 'enya', 'given', 'us', 'great', 'music', 'still', 'unique', 'perspective', 'flow', 'rhythm', 'music', 'remains', 'timeless', 'fresh', 'years', 'release'], ['favorite', 'enya', 'album', 'date', 'even', 'writing', 'review', 'come', 'close', 'inner', 'feelings', 'music', 'first', 'song', 'title', 'track', 'quot', 'memory', 'trees', 'quot', 'beautiful', 'song', 'ever', 'heard', 'quiet', 'strings', 'layered', 'voices', 'shy', 'piano', 'climax', 'percussion', 'complex', 'vocal', 'parts', 'song', 'gorgeously', 'triumphant', 'quot', 'anywhere', 'quot', 'catchy', 'beautiful', 'song', 'brings', 'mind', 'wandering', 'maze', 'another', 'highlight', 'album', 'quot', 'pax', 'deorum', 'quot', 'first', 'time', 'heard', 'thought', 'group', 'hooded', 'figures', 'temple', 'performing', 'ceremony', 'enya', 'shows', 'low', 'range', 'piece', 'also', 'interesting', 'combines', 'two', 'different', 'languages', 'two', 'different', 'religious', 'ideas', 'polytheism', 'romans', ' ...

# %%
print(review_year_dict[1998])
# Out:
# [['quot', 'offers', 'enya', 'heart', 'selections', 'special', 'meaning', 'due', 'loss', 'one', 'special', 'really', 'read', 'words', 'way', 'home', 'see', 'thing', 'heart', 'one', 'love', 'concerned', 'rather', 'different', 'type', 'composition', 'enya', 'offered', 'quot', 'anywhere', 'quot', 'obligatory', 'swing', 'choirs', 'future', 'la', 'sonadora', 'really', 'moving', 'amp', 'spiritual', 'great', 'tracks', 'cd'], ['enya', 'fan', 'sure', 'cd', 'offers', 'nice', 'quot', 'mix', 'quot', 'lack', 'better', 'word', 'styles', 'quot', 'pax', 'deorum', 'quot', 'chilling', 'latin', 'refrains', 'quot', 'la', 'sonadora', 'quot', 'spanish', 'torreador', 'ballad', 'feeling', 'absolutely', 'beautiful', 'refrains', 'quot', 'athair', 'ar', 'seamh', 'quot', 'display', 'vocal', 'writing', 'talents', 'deny', 'quot', 'china', 'roses', 'quot', 'one', 'smooth', 'sweet', 'vocal', 'pieces', 'grace', 'cd', 'memory', 'trees', 'stellar', 'enya', 'disc'], ['bad', 'cars', 'lumped', 'classic', 'rock', 'zeppelin', 'amp', 'like', 'debut', 'pop', 'masterpiece', 'risk', 'dig', 'hoary', 'cliches', 'still', 'sounds', 'fresh', 'today'], ['thank', 'brian', 'giving', 'remarkable', 'gift', 'world', 'pet', 'sounds', 'favorite', 'album', 'since', 'first', 'became', 'aware', 'back', 'geeky', 'gawky', 'teenager', 'unsure', 'place', 'world', 'pet', 'sounds', 'told', 'alone', 'helped', 'lot', 'tough', 'times', 'made', 'good', 'days', 'better', 'defy', 'anyone', 'listen', 'pet', 'sounds', 'open', 'mind', 'heart', 'come', 'away', 'love', 'album', 'music', 'get', 'better'], ['everyone', 'heard', 'pet', 'sounds', 'greatest', 'album', 'time', 'come', 'think', 'true', 'immediately', 'first', 'listening', 'anyone', 'recognize', 'pet', 'sounds', 'contains', 'beautiful', 'harmony', 'record', 'would', 'nice', 'sloop', 'john', 'b', 'god', 'knows', 'inarguably', 'three', 'beautiful', 'songs', 'music', 'wait', 'beneath', 'wonder', 'sound', 'mixing', 'would', 'make', 'phil', 'spector', 'drool', 'story', 'angst', 'yearning', 'emotions', 'young', 'people', 'experience', 'story', 'person', 'love', 'chronicling', 'highs', 'lows', 'daydreams', 'wishes', 'would', 'nice', 'bittersweet', 'denoument', 'caroline', 'obvious', 'hearfelt', 'statement', 'sprinkled', 'within', 'masterpieces', 'made', 'times', 'obviously', 'personal', 'messages', 'one', 'greatest', 'musical', 'geniuses', 'twentieth', 'century', 'fear', 'surfin', 'safari', 'emotional', 'groundbreaking', 'classic'], ['pet', 'sounds', 'one', 'best', 'listenable', 'albums', 'brian', 'wilson', 'trying', 'best', 'beatles', 'rubber', 'soul', 'believe', 'blew', 'know', 'many', 'times', 'listened', 'far', 'tired', 'one', 'rock', 'memorable', 'masterpieces', 'miss'], ['great', 'companion', 'pure', 'samba', 'without', 'byrd', 'went', 'brazil', 'heard', 'unknown', 'antonio', 'carlos', 'jobim', 'played', 'jobim', 'records', 'stan', 'getz', 'got', 'keter', 'betts', 'two', 'drummers', 'went', 'soul', 'unitarian', 'church', 'dc', 'created', 'first', 'bossa', 'nova', 'samba', 'record', 'us', 'monster', 'hit', 'desafinado', 'changed', 'america', 'jazz', 'forever', 'decade', 'every', 'jazz', 'player', 'tried', 'imitate', 'best', 'selling', 'jazz', 'cd', 'decade', 'good', 'number', 'one', 'hit', 'billboard', 'jazz', 'pop', 'rock', 'charts', 'time', 'jazz', 'album', 'album', 'type', 'even', 'kind', 'blue', 'even', 'getz', 'ever', 'achieved', 'subtle', 'polyrhythym', 'drumming', 'deppenschmidt', 'riechenbach', 'add', 'authentic', 'carnivale', 'touch', 'traditional', 'samba', 'polyrhythm', 'cd', 'subsequent', 'getz', 'bossa', 'nova', 'cd', 'bn', 'cd', 'subsequent', 'artists', 'tried', 'capitalize', 'om', 'bn', 'craze', 'hear', 'e', 'luxo', 'floats', 'soars', 'desafinado', 'portuguese', 'offkey', 'e', 'luxo', 'bahia', 'authentic', 'brazilian', 'getz', 'samba', 'stan', 'make', 'note', 'blue', 'fog', 'note', 'count', 'beautiful', 'lyrical', 'soaring', 'one', 'ten', 'best', 'jazz', 'recordings', 'ever', 'made', 'updateyes', 'true', 'wonderful', 'sax', 'man',  ...

# %%
#the below variable would be used as a parameter in DTM: how many documents per year?
time_seq = [len(review_year_dict[year]) for year in range(1998,2015)]

# %%
#sort reviews by year
sorted_reviews = []
for y in range(1998,2015):
    for review in review_year_dict[y]:
        sorted_reviews.append(review)#review_year_dict[y])
# Out:
# ['enya', 'fan', 'sure', 'cd', 'offers', 'nice', 'quot', 'mix', 'quot', 'lack', 'better', 'word', 'styles', 'quot', 'pax', 'deorum', 'quot', 'chilling', 'latin', 'refrains', 'quot', 'la', 'sonadora', 'quot', 'spanish', 'torreador', 'ballad', 'feeling', 'absolutely', 'beautiful', 'refrains', 'quot', 'athair', 'ar', 'seamh', 'quot', 'display', 'vocal', 'writing', 'talents', 'deny', 'quot', 'china', 'roses', 'quot', 'one', 'smooth', 'sweet', 'vocal', 'pieces', 'grace', 'cd', 'memory', 'trees', 'stellar', 'enya', 'disc']

# %%
#use Blei's dynamic topic modeling package
class DTMcorpus(corpora.textcorpus.TextCorpus):

    def get_texts(self):
        return self.input

    def __len__(self):
        return len(self.input)

corpus = DTMcorpus(sorted_reviews)

# %%
dtm_path = "C:/Users/UserAcc/AnacondaProjects/dtm-win64.exe"
model = DtmModel(dtm_path, corpus, time_seq, num_topics=10,
                 id2word=corpus.dictionary, initialize_lda=True)

# %%
#show top 10 topicsdtm_path = "C:/Users/UserAcc/AnacondaProjects/dtm-win64.exe"
model = DtmModel(dtm_path, corpus, time_seq, num_topics=10,
                 id2word=corpus.dictionary, initialize_lda=True)

#show top 10 topics for year 0 (1998) - topic #1
model.show_topic(topicid=1, time=0, topn=10)

#make a dictionary of all topics over all years
list_words = defaultdict(lambda: defaultdict(list))
for topicno in range(10): #topics
    for y in range(17): #years
        list_words[topicno][y].append(model.show_topic(topicid=topicno, time=y, topn=10))

list_words
